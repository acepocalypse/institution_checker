# %% [markdown]
# # Institution Checker - Quick Runner
# A minimal notebook for processing one or more names against the configured institution.

# %% [markdown]
# ## 📚 How to Use
#
# ### Quick Start (3 steps):
# 1. **🔄 RELOAD** (Cell 10): Load all fixes ⭐
# 2. **Configure** (Cell 4): Set INPUT_MODE and names
# 3. **Run Pipeline** (Cell 9): Process all names
#
# ### Full Workflow:
# 1. **Setup** → Cell 3: Import modules
# 2. **Configure** → Cell 4: Set input and parameters
# 3. **Resolve Names** → Cell 7: Validate name list
# 4. **🔄 RELOAD MODULE** → Cell 10: Load fixes ⭐ **START HERE**
# 5. **🔬 Diagnose** → Cell 13: Verify LLM is working correctly
# 6. **Debug Single** → Cell 15: Test problematic names
# 7. **Run Pipeline** → Cell 9: Process all names
# 8. **Quality Check** → Cell 19: Analyze results
# 9. **Retry Failed** → Cell 17: Auto-retry any remaining errors
# 10. **Export** → Cell 22: Save to Excel
#
# ### 🧠 What Was Fixed:
# - ✅ **REMOVED max_tokens** - unlimited for thinking models
# - ✅ **Fixed format string error** - escaped curly braces
# - ✅ **IMPROVED current/past detection** - smarter signal counting
# - ✅ **Enhanced prompt** - clearer temporal guidance
# - ✅ **Fixed temperature** (0.0) - consistent reasoning
#
# ### 💡 Current/Past Detection Logic:
# **Simple, evidence-based approach:**
# - Counts "current" terms (is, currently, works at) vs "past" terms (was, former, retired)
# - Detects ended date ranges like "2010-2015"
# - Checks if person is currently at another institution
# - Overrides LLM classification when evidence is strong (3+ signals)

# %%
import asyncio
import platform
import sys
from pathlib import Path
from typing import List, Optional

import pandas as pd

from institution_checker import (
    INSTITUTION,
    FileSourceContext,
    close_search_clients,
    close_session,
    expand_results_to_source,
    resolve_names,
    run_pipeline,
)

print(f"Python: {sys.version.split()[0]} on {platform.platform()}")
print(f"Pandas: {pd.__version__}")
print(f"Institution: {INSTITUTION}")
# Out:
# Python: 3.12.7 on Windows-11-10.0.26100-SP0
# Pandas: 2.3.1
# Institution: Purdue University

# %%
# Input options: "single", "list", "file"
INPUT_MODE = "list"
SINGLE_NAME = "Christopher L. Eisgruber"
NAME_LIST = [
    "Robert Duncan",
    "Mitch Daniels",
    "Morgan Furze",
    "Connie Weaver",
    "Geoffrey Hinton",
    "Albert Warner Overhauser",
    "Isidor Isaac Rabi",
    "Chintamani Nagesa Ramachandra Rao",
    "Jane Goodall",
    "Marie Curie",
    "Nicholas Rauh",
    "France Cordova",
    "Steve Amireault",
    "Roy Dejoie",
    "Jozef Kokini",
    "Paul Alivisatos",
    "Vernon W. Ruttan",
    "William H. Gass",
    "Axel Hoffmann",
    "Matthew Lanham",
]
INPUT_FILE = r"E:\Ace\To be sorted\Purdue Trial Set HP Awardees 2024-10-23.xlsx"
FILE_COLUMN = "name"
FILE_SHEET: Optional[str] = None  # Only used for Excel sources

BATCH_SIZE = 8
INTER_BATCH_DELAY = 2.5  # Seconds to wait between batches (helps prevent rate limiting)
USE_ENHANCED_SEARCH = True
RUN_NETWORK_TESTS = True
EXPORT_PATH = "data/results.csv"  # Set to "" to skip writing

# %%
FILE_CONTEXT: Optional[FileSourceContext] = None


def prepare_names() -> List[str]:
    """Resolve names based on notebook configuration while tracking file context."""
    global FILE_CONTEXT
    mode = INPUT_MODE.lower().strip()
    if mode == "file":
        FILE_CONTEXT = FileSourceContext.from_path(
            INPUT_FILE,
            column=FILE_COLUMN,
            sheet=FILE_SHEET or None,
        )
        return FILE_CONTEXT.unique_names()

    FILE_CONTEXT = None
    return resolve_names(
        input_mode=mode,
        single_name=SINGLE_NAME,
        name_list=NAME_LIST,
        input_file=INPUT_FILE,
        file_column=FILE_COLUMN,
        file_sheet=FILE_SHEET or None,
    )

# %% [markdown]
# ## Resolve Names
# Build the list of names based on the selected input mode.

# %%
names_to_check: List[str] = []
try:
    names_to_check = prepare_names()
    if not names_to_check:
        print("No names to process. Update the configuration cell.")
    else:
        print(f"Prepared {len(names_to_check)} name(s):")
        for item in names_to_check:
            print(f" - {item}")
except Exception as exc:
    names_to_check = []
    print(f"Configuration error: {exc}")
# Out:
# Prepared 20 name(s):
#  - Robert Duncan
#  - Mitch Daniels
#  - Morgan Furze
#  - Connie Weaver
#  - Geoffrey Hinton
#  - Albert Warner Overhauser
#  - Isidor Isaac Rabi
#  - Chintamani Nagesa Ramachandra Rao
#  - Jane Goodall
#  - Marie Curie
#  - Nicholas Rauh
#  - France Cordova
#  - Steve Amireault
#  - Roy Dejoie
#  - Jozef Kokini
#  - Paul Alivisatos
#  - Vernon W. Ruttan
#  - William H. Gass
#  - Axel Hoffmann
#  - Matthew Lanham
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Run Pipeline
# Executes the async pipeline using the enhanced search client unless disabled.

# %%
pipeline_results = []

if not names_to_check:
    print("No names to process.")
elif not RUN_NETWORK_TESTS:
    print("RUN_NETWORK_TESTS is False; skipping live pipeline execution.")
else:
    print("Starting pipeline with enhanced progress tracking and auto-retry...")
    pipeline_results = await run_pipeline(
        names_to_check,
        batch_size=max(1, int(BATCH_SIZE)),
        use_enhanced_search=USE_ENHANCED_SEARCH,
        inter_batch_delay=INTER_BATCH_DELAY,
        debug=False,  # Enable debug mode for detailed logging
    )
    print(f"Pipeline completed (including auto-retry). Processed {len(pipeline_results)} record(s).")
# Out:
# Starting pipeline with enhanced progress tracking and auto-retry...
# [PIPELINE] Starting: 20 name(s) in 3 batch(es) using enhanced search
# [PIPELINE] Batch size: 8, Inter-batch delay: 2.5s
#
# [PIPELINE] ===== BATCH 1/3 =====
# [PIPELINE] Names in this batch: ['Robert Duncan', 'Mitch Daniels', 'Morgan Furze', 'Connie Weaver', 'Geoffrey Hinton', 'Albert Warner Overhauser', 'Isidor Isaac Rabi', 'Chintamani Nagesa Ramachandra Rao']
# [BATCH] Processing 8 names: Robert Duncan, Mitch Daniels, Morgan Furze, Connie Weaver, Geoffrey Hinton, Albert Warner Overhauser, Isidor Isaac Rabi, Chintamani Nagesa Ramachandra Rao
# [BATCH] Phase 1: Running searches in parallel for all 8 names
# [PROGRESS] Starting search for: Robert Duncan
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Mitch Daniels
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Morgan Furze
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Connie Weaver
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Geoffrey Hinton
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Albert Warner Overhauser
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Isidor Isaac Rabi
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Chintamani Nagesa Ramachandra Rao
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Basic search returned 18 results (15 high-quality), sufficient for analysis
# [PROGRESS] Search completed for Connie Weaver in 2.7s, found 18 results
# [PROGRESS] Basic search returned 16 results (9 high-quality), sufficient for analysis
# [PROGRESS] Search completed for Morgan Furze in 2.7s, found 16 results
# [PROGRESS] Basic search returned 14 results (11 high-quality), sufficient for analysis
# [PROGRESS] Search completed for Robert Duncan in 3.5s, found 14 results
# [PROGRESS] Basic search returned 11 results (5 high-quality), sufficient for analysis
# [PROGRESS] Search completed for Chintamani Nagesa Ramachandra Rao in 2.8s, found 11 results
# [PROGRESS] Basic search returned 2 results (0 high-quality), escalating to enhanced search for thorough verification...
# [PROGRESS] Basic search returned 19 results (16 high-quality), sufficient for analysis
# [PROGRESS] Search completed for Albert Warner Overhauser in 2.9s, found 19 results
# [PROGRESS] Basic search returned 20 results (17 high-quality), sufficient for analysis
# [PROGRESS] Search completed for Mitch Daniels in 3.0s, found 20 results
# [PROGRESS] Basic search returned 6 results (4 high-quality), escalating to enhanced search for thorough verification...
# [PROGRESS] Search completed for Isidor Isaac Rabi in 45.2s, found 7 results
# [PROGRESS] Search completed for Geoffrey Hinton in 45.2s, found 14 results
# [BATCH] Phase 1 completed in 46.0s
# [BATCH] Search succeeded for Robert Duncan: 14 results
# [BATCH] Search succeeded for Mitch Daniels: 20 results
# [BATCH] Search succeeded for Morgan Furze: 16 results
# [BATCH] Search succeeded for Connie Weaver: 18 results
# [BATCH] Search succeeded for Geoffrey Hinton: 14 results
# [BATCH] Search succeeded for Albert Warner Overhauser: 19 results
# [BATCH] Search succeeded for Isidor Isaac Rabi: 7 results
# [BATCH] Search succeeded for Chintamani Nagesa Ramachandra Rao: 11 results
# [BATCH] Phase 2: Running LLM analysis in parallel for all 8 names (max 5 concurrent)
# [PROGRESS] Starting LLM analysis for: Robert Duncan
# [PROGRESS] Starting LLM analysis for: Mitch Daniels
# [PROGRESS] Starting LLM analysis for: Morgan Furze
# [PROGRESS] Starting LLM analysis for: Connie Weaver
# [PROGRESS] Starting LLM analysis for: Geoffrey Hinton
# [PROGRESS] LLM analysis completed for Robert Duncan in 1.5s
# [PROGRESS] LLM analysis completed for Mitch Daniels in 1.5s
# [PROGRESS] Starting LLM analysis for: Albert Warner Overhauser
# [PROGRESS] LLM analysis completed for Geoffrey Hinton in 1.5s
# [PROGRESS] Starting LLM analysis for: Isidor Isaac Rabi
# [PROGRESS] LLM analysis completed for Connie Weaver in 1.5s
# [PROGRESS] Starting LLM analysis for: Chintamani Nagesa Ramachandra Rao
# [PROGRESS] LLM analysis completed for Morgan Furze in 1.5s
# [PROGRESS] LLM analysis completed for Albert Warner Overhauser in 1.5s
# [PROGRESS] LLM analysis completed for Isidor Isaac Rabi in 1.5s
# [PROGRESS] LLM analysis completed for Chintamani Nagesa Ramachandra Rao in 1.5s
# [BATCH] Phase 2 completed in 3.0s
# [BATCH] Completed 1/8 (Robert Duncan) in 49.0s
# [--] Robert Duncan: no confirmed connection to Purdue University
# [BATCH] Completed 2/8 (Mitch Daniels) in 49.0s
# [--] Mitch Daniels: no confirmed connection to Purdue University
# [BATCH] Completed 3/8 (Morgan Furze) in 49.0s
# [--] Morgan Furze: no confirmed connection to Purdue University
# [BATCH] Completed 4/8 (Connie Weaver) in 49.0s
# [--] Connie Weaver: no confirmed connection to Purdue University
# [BATCH] Completed 5/8 (Geoffrey Hinton) in 49.0s
# [--] Geoffrey Hinton: no confirmed connection to Purdue University
# [BATCH] Completed 6/8 (Albert Warner Overhauser) in 49.0s
# [--] Albert Warner Overhauser: no confirmed connection to Purdue University
# [BATCH] Completed 7/8 (Isidor Isaac Rabi) in 49.0s
# [--] Isidor Isaac Rabi: no confirmed connection to Purdue University
# [BATCH] Completed 8/8 (Chintamani Nagesa Ramachandra Rao) in 49.0s
# [--] Chintamani Nagesa Ramachandra Rao: no confirmed connection to Purdue University
# [BATCH] Batch completed in 49.0s (search: 46.0s, LLM: 3.0s)
# [PIPELINE] Batch 1 completed in 49.0s
# [PIPELINE] Total pipeline time so far: 49.0s
# [PIPELINE] Total results collected: 8
# [PIPELINE] Partial results written to data/results_partial.csv
# [PIPELINE] Starting cleanup and 2.5s delay before batch 2...
# [PIPELINE] Cleanup completed in 0.0s
# [PIPELINE] Waiting 2.5s before next batch...
# [PIPELINE] Ready to start batch 2
#
# [PIPELINE] ===== BATCH 2/3 =====
# [PIPELINE] Names in this batch: ['Jane Goodall', 'Marie Curie', 'Nicholas Rauh', 'France Cordova', 'Steve Amireault', 'Roy Dejoie', 'Jozef Kokini', 'Paul Alivisatos']
# [BATCH] Processing 8 names: Jane Goodall, Marie Curie, Nicholas Rauh, France Cordova, Steve Amireault, Roy Dejoie, Jozef Kokini, Paul Alivisatos
# [BATCH] Phase 1: Running searches in parallel for all 8 names
# [PROGRESS] Starting search for: Jane Goodall
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Marie Curie
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Nicholas Rauh
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: France Cordova
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Steve Amireault
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Roy Dejoie
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Jozef Kokini
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Paul Alivisatos
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Basic search returned 17 results (12 high-quality), sufficient for analysis
# [PROGRESS] Search completed for Jozef Kokini in 0.9s, found 17 results
# [PROGRESS] Basic search returned 10 results (6 high-quality), sufficient for analysis
# [PROGRESS] Search completed for Jane Goodall in 0.9s, found 10 results
# [PROGRESS] Basic search returned 18 results (11 high-quality), sufficient for analysis
# [PROGRESS] Search completed for Steve Amireault in 1.0s, found 18 results
# [PROGRESS] Basic search returned 16 results (14 high-quality), sufficient for analysis
# [PROGRESS] Search completed for Roy Dejoie in 1.1s, found 16 results
# [PROGRESS] Basic search returned 6 results (6 high-quality), escalating to enhanced search for thorough verification...
# [PROGRESS] Basic search returned 12 results (10 high-quality), sufficient for analysis
# [PROGRESS] Search completed for Nicholas Rauh in 1.1s, found 12 results
# [PROGRESS] Basic search returned 3 results (2 high-quality), escalating to enhanced search for thorough verification...
# [PROGRESS] Basic search returned 6 results (1 high-quality), escalating to enhanced search for thorough verification...
# [PROGRESS] Search completed for Paul Alivisatos in 43.8s, found 15 results
# [PROGRESS] Search completed for France Cordova in 43.8s, found 9 results
# [PROGRESS] Search completed for Marie Curie in 44.1s, found 19 results
# [BATCH] Phase 1 completed in 44.1s
# [BATCH] Search succeeded for Jane Goodall: 10 results
# [BATCH] Search succeeded for Marie Curie: 19 results
# [BATCH] Search succeeded for Nicholas Rauh: 12 results
# [BATCH] Search succeeded for France Cordova: 9 results
# [BATCH] Search succeeded for Steve Amireault: 18 results
# [BATCH] Search succeeded for Roy Dejoie: 16 results
# [BATCH] Search succeeded for Jozef Kokini: 17 results
# [BATCH] Search succeeded for Paul Alivisatos: 15 results
# [BATCH] Phase 2: Running LLM analysis in parallel for all 8 names (max 5 concurrent)
# [PROGRESS] Starting LLM analysis for: Jane Goodall
# [PROGRESS] Starting LLM analysis for: Marie Curie
# [PROGRESS] Starting LLM analysis for: Nicholas Rauh
# [PROGRESS] Starting LLM analysis for: France Cordova
# [PROGRESS] Starting LLM analysis for: Steve Amireault
# [PROGRESS] LLM analysis completed for Jane Goodall in 1.5s
# [PROGRESS] LLM analysis completed for Marie Curie in 1.5s
# [PROGRESS] Starting LLM analysis for: Roy Dejoie
# [PROGRESS] LLM analysis completed for Steve Amireault in 1.5s
# [PROGRESS] Starting LLM analysis for: Jozef Kokini
# [PROGRESS] LLM analysis completed for France Cordova in 1.5s
# [PROGRESS] Starting LLM analysis for: Paul Alivisatos
# [PROGRESS] LLM analysis completed for Nicholas Rauh in 1.5s
# [PROGRESS] LLM analysis completed for Roy Dejoie in 1.5s
# [PROGRESS] LLM analysis completed for Jozef Kokini in 1.5s
# [PROGRESS] LLM analysis completed for Paul Alivisatos in 1.5s
# [BATCH] Phase 2 completed in 3.0s
# [BATCH] Completed 1/8 (Jane Goodall) in 47.1s
# [--] Jane Goodall: no confirmed connection to Purdue University
# [BATCH] Completed 2/8 (Marie Curie) in 47.1s
# [--] Marie Curie: no confirmed connection to Purdue University
# [BATCH] Completed 3/8 (Nicholas Rauh) in 47.1s
# [--] Nicholas Rauh: no confirmed connection to Purdue University
# [BATCH] Completed 4/8 (France Cordova) in 47.1s
# [--] France Cordova: no confirmed connection to Purdue University
# [BATCH] Completed 5/8 (Steve Amireault) in 47.1s
# [--] Steve Amireault: no confirmed connection to Purdue University
# [BATCH] Completed 6/8 (Roy Dejoie) in 47.1s
# [--] Roy Dejoie: no confirmed connection to Purdue University
# [BATCH] Completed 7/8 (Jozef Kokini) in 47.1s
# [--] Jozef Kokini: no confirmed connection to Purdue University
# [BATCH] Completed 8/8 (Paul Alivisatos) in 47.1s
# [--] Paul Alivisatos: no confirmed connection to Purdue University
# [BATCH] Batch completed in 47.1s (search: 44.1s, LLM: 3.0s)
# [PIPELINE] Batch 2 completed in 47.1s
# [PIPELINE] Total pipeline time so far: 98.6s
# [PIPELINE] Total results collected: 16
# [PIPELINE] Partial results written to data/results_partial.csv
# [PIPELINE] Starting cleanup and 2.5s delay before batch 3...
# [PIPELINE] Cleanup completed in 0.0s
# [PIPELINE] Waiting 2.5s before next batch...
# [PIPELINE] Ready to start batch 3
#
# [PIPELINE] ===== BATCH 3/3 =====
# [PIPELINE] Names in this batch: ['Vernon W. Ruttan', 'William H. Gass', 'Axel Hoffmann', 'Matthew Lanham']
# [BATCH] Processing 4 names: Vernon W. Ruttan, William H. Gass, Axel Hoffmann, Matthew Lanham
# [BATCH] Phase 1: Running searches in parallel for all 4 names
# [PROGRESS] Starting search for: Vernon W. Ruttan
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: William H. Gass
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Axel Hoffmann
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Matthew Lanham
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Basic search returned 16 results (14 high-quality), sufficient for analysis
# [PROGRESS] Search completed for Matthew Lanham in 0.9s, found 16 results
# [PROGRESS] Basic search returned 1 results (0 high-quality), escalating to enhanced search for thorough verification...
# [PROGRESS] Basic search returned 15 results (8 high-quality), sufficient for analysis
# [PROGRESS] Search completed for Vernon W. Ruttan in 0.9s, found 15 results
# [PROGRESS] Basic search returned 19 results (14 high-quality), sufficient for analysis
# [PROGRESS] Search completed for William H. Gass in 1.1s, found 19 results
# [PROGRESS] Search completed for Axel Hoffmann in 42.7s, found 8 results
# [BATCH] Phase 1 completed in 42.7s
# [BATCH] Search succeeded for Vernon W. Ruttan: 15 results
# [BATCH] Search succeeded for William H. Gass: 19 results
# [BATCH] Search succeeded for Axel Hoffmann: 8 results
# [BATCH] Search succeeded for Matthew Lanham: 16 results
# [BATCH] Phase 2: Running LLM analysis in parallel for all 4 names (max 5 concurrent)
# [PROGRESS] Starting LLM analysis for: Vernon W. Ruttan
# [PROGRESS] Starting LLM analysis for: William H. Gass
# [PROGRESS] Starting LLM analysis for: Axel Hoffmann
# [PROGRESS] Starting LLM analysis for: Matthew Lanham
# [PROGRESS] LLM analysis completed for Vernon W. Ruttan in 1.5s
# [PROGRESS] LLM analysis completed for William H. Gass in 1.5s
# [PROGRESS] LLM analysis completed for Matthew Lanham in 1.5s
# [PROGRESS] LLM analysis completed for Axel Hoffmann in 1.5s
# [BATCH] Phase 2 completed in 1.5s
# [BATCH] Completed 1/4 (Vernon W. Ruttan) in 44.2s
# [--] Vernon W. Ruttan: no confirmed connection to Purdue University
# [BATCH] Completed 2/4 (William H. Gass) in 44.2s
# [--] William H. Gass: no confirmed connection to Purdue University
# [BATCH] Completed 3/4 (Axel Hoffmann) in 44.2s
# [--] Axel Hoffmann: no confirmed connection to Purdue University
# [BATCH] Completed 4/4 (Matthew Lanham) in 44.2s
# [--] Matthew Lanham: no confirmed connection to Purdue University
# [BATCH] Batch completed in 44.2s (search: 42.7s, LLM: 1.5s)
# [PIPELINE] Batch 3 completed in 44.2s
# [PIPELINE] Total pipeline time so far: 145.3s
# [PIPELINE] Total results collected: 20
# [PIPELINE] Partial results written to data/results_partial.csv
#
# [PIPELINE] ===== RETRY PHASE =====
# [PIPELINE] Found 20 failed record(s), retrying...
# [PIPELINE] Failed names: Robert Duncan, Mitch Daniels, Morgan Furze, Connie Weaver, Geoffrey Hinton, Albert Warner Overhauser, Isidor Isaac Rabi, Chintamani Nagesa Ramachandra Rao, Jane Goodall, Marie Curie, Nicholas Rauh, France Cordova, Steve Amireault, Roy Dejoie, Jozef Kokini, Paul Alivisatos, Vernon W. Ruttan, William H. Gass, Axel Hoffmann, Matthew Lanham
# [RETRY] Processing batch 1/5: ['Robert Duncan', 'Mitch Daniels', 'Morgan Furze', 'Connie Weaver']
# [BATCH] Processing 4 names: Robert Duncan, Mitch Daniels, Morgan Furze, Connie Weaver
# [BATCH] Phase 1: Running searches in parallel for all 4 names
# [PROGRESS] Starting search for: Robert Duncan
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Mitch Daniels
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Morgan Furze
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Connie Weaver
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Basic search returned 14 results (11 high-quality), sufficient for analysis
# [PROGRESS] Search completed for Robert Duncan in 0.8s, found 14 results
# [PROGRESS] Basic search returned 19 results (16 high-quality), sufficient for analysis
# [PROGRESS] Search completed for Connie Weaver in 1.0s, found 19 results
# [PROGRESS] Basic search returned 14 results (9 high-quality), sufficient for analysis
# [PROGRESS] Search completed for Morgan Furze in 1.1s, found 14 results
# [PROGRESS] Basic search returned 20 results (18 high-quality), sufficient for analysis
# [PROGRESS] Search completed for Mitch Daniels in 1.2s, found 20 results
# [BATCH] Phase 1 completed in 1.2s
# [BATCH] Search succeeded for Robert Duncan: 14 results
# [BATCH] Search succeeded for Mitch Daniels: 20 results
# [BATCH] Search succeeded for Morgan Furze: 14 results
# [BATCH] Search succeeded for Connie Weaver: 19 results
# [BATCH] Phase 2: Running LLM analysis in parallel for all 4 names (max 5 concurrent)
# [PROGRESS] Starting LLM analysis for: Robert Duncan
# [PROGRESS] Starting LLM analysis for: Mitch Daniels
# [PROGRESS] Starting LLM analysis for: Morgan Furze
# [PROGRESS] Starting LLM analysis for: Connie Weaver
# [PROGRESS] LLM analysis completed for Robert Duncan in 1.5s
# [PROGRESS] LLM analysis completed for Mitch Daniels in 1.5s
# [PROGRESS] LLM analysis completed for Connie Weaver in 1.5s
# [PROGRESS] LLM analysis completed for Morgan Furze in 1.5s
# [BATCH] Phase 2 completed in 1.5s
# [BATCH] Completed 1/4 (Robert Duncan) in 2.7s
# [--] Robert Duncan: no confirmed connection to Purdue University
# [BATCH] Completed 2/4 (Mitch Daniels) in 2.7s
# [--] Mitch Daniels: no confirmed connection to Purdue University
# [BATCH] Completed 3/4 (Morgan Furze) in 2.7s
# [--] Morgan Furze: no confirmed connection to Purdue University
# [BATCH] Completed 4/4 (Connie Weaver) in 2.7s
# [--] Connie Weaver: no confirmed connection to Purdue University
# [BATCH] Batch completed in 2.7s (search: 1.2s, LLM: 1.5s)
# [RETRY] Waiting 2.5s before next retry batch...
# [RETRY] Processing batch 2/5: ['Geoffrey Hinton', 'Albert Warner Overhauser', 'Isidor Isaac Rabi', 'Chintamani Nagesa Ramachandra Rao']
# [BATCH] Processing 4 names: Geoffrey Hinton, Albert Warner Overhauser, Isidor Isaac Rabi, Chintamani Nagesa Ramachandra Rao
# [BATCH] Phase 1: Running searches in parallel for all 4 names
# [PROGRESS] Starting search for: Geoffrey Hinton
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Albert Warner Overhauser
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Isidor Isaac Rabi
# [PROGRESS] Trying basic search first for efficiency...
# [PROGRESS] Starting search for: Chintamani Nagesa Ramachandra Rao
# [PROGRESS] Trying basic search first for efficiency...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File <frozen runpy>:198, in _run_module_as_main(mod_name, alter_argv)
#
# File <frozen runpy>:88, in _run_code(code, run_globals, init_globals, mod_name, mod_spec, pkg_name, script_name)
#
# File c:\Users\setiawa\AppData\Local\anaconda3\Lib\site-packages\ipykernel_launcher.py:17
#      13     del sys.path[0]
#      15 from ipykernel import kernelapp as app
# ---> 17 app.launch_new_instance()
#
# File c:\Users\setiawa\AppData\Local\anaconda3\Lib\site-packages\traitlets\config\application.py:1075, in Application.launch_instance(cls, argv, **kwargs)
#    1073 app = cls.instance(**kwargs)
#    1074 app.initialize(argv)
# -> 1075 app.start()
#
# File c:\Users\setiawa\AppData\Local\anaconda3\Lib\site-packages\ipykernel\kernelapp.py:701, in IPKernelApp.start(self)
#     699 else:
#     700     try:
# --> 701         self.io_loop.start()
#     702     except KeyboardInterrupt:
#     703         pass
#
# File c:\Users\setiawa\AppData\Local\anaconda3\Lib\site-packages\tornado\platform\asyncio.py:205, in BaseAsyncIOLoop.start(self)
#     204 def start(self) -> None:
# --> 205     self.asyncio_loop.run_forever()
#
# File c:\Users\setiawa\AppData\Local\anaconda3\Lib\asyncio\windows_events.py:322, in ProactorEventLoop.run_forever(self)
#     320     assert self._self_reading_future is None
#     321     self.call_soon(self._loop_self_reading)
# --> 322     super().run_forever()
#     323 finally:
#     324     if self._self_reading_future is not None:
#
# File c:\Users\setiawa\AppData\Local\anaconda3\Lib\asyncio\base_events.py:641, in BaseEventLoop.run_forever(self)
#     639 events._set_running_loop(self)
#     640 while True:
# --> 641     self._run_once()
#     642     if self._stopping:
#     643         break
#
# File c:\Users\setiawa\AppData\Local\anaconda3\Lib\asyncio\base_events.py:1948, in BaseEventLoop._run_once(self)
#    1945     when = self._scheduled[0]._when
#    1946     timeout = min(max(0, when - self.time()), MAXIMUM_SELECT_TIMEOUT)
# -> 1948 event_list = self._selector.select(timeout)
#    1949 self._process_events(event_list)
#    1950 # Needed to break cycles when an exception occurs.
#
# File c:\Users\setiawa\AppData\Local\anaconda3\Lib\asyncio\windows_events.py:445, in IocpProactor.select(self, timeout)
#     443 def select(self, timeout=None):
#     444     if not self._results:
# --> 445         self._poll(timeout)
#     446     tmp = self._results
#     447     self._results = []
#
# File c:\Users\setiawa\AppData\Local\anaconda3\Lib\asyncio\windows_events.py:774, in IocpProactor._poll(self, timeout)
#     771         raise ValueError("timeout too big")
#     773 while True:
# --> 774     status = _overlapped.GetQueuedCompletionStatus(self._iocp, ms)
#     775     if status is None:
#     776         break
#
# File c:\Users\setiawa\AppData\Local\anaconda3\Lib\site-packages\pyppeteer\launcher.py:153, in Launcher.launch.<locals>._close_process(*args, **kwargs)
#     151 def _close_process(*args: Any, **kwargs: Any) -> None:
#     152     if not self.chromeClosed:
# --> 153         self._loop.run_until_complete(self.killChrome())
#
# File c:\Users\setiawa\AppData\Local\anaconda3\Lib\asyncio\base_events.py:663, in BaseEventLoop.run_until_complete(self, future)
#     652 """Run until the Future is done.
#     653
#     654 If the argument is a coroutine, it is wrapped in a Task.
#    (...)
#     660 Return the Future's result, or raise its exception.
#     661 """
#     662 self._check_closed()
# --> 663 self._check_running()
#     665 new_task = not futures.isfuture(future)
#     666 future = tasks.ensure_future(future, loop=self)
#
# File c:\Users\setiawa\AppData\Local\anaconda3\Lib\asyncio\base_events.py:622, in BaseEventLoop._check_running(self)
#     620 def _check_running(self):
#     621     if self.is_running():
# --> 622         raise RuntimeError('This event loop is already running')
#     623     if events._get_running_loop() is not None:
#     624         raise RuntimeError(
#     625             'Cannot run the event loop while another loop is running')
#
# RuntimeError: This event loop is already running

# %%
# Reload the module with ALL fixes for thinking models
import importlib
import institution_checker as ic

ic = importlib.reload(ic)

from institution_checker import (
    INSTITUTION,
    FileSourceContext,
    close_search_clients,
    close_session,
    expand_results_to_source,
    resolve_names,
    run_pipeline,
)

print("=" * 70)
print("✓ INSTITUTION CHECKER RELOADED - ALL FIXES APPLIED")
print("=" * 70)
print("\n🧠 YOUR MODEL: GPT-OSS 20B (Thinking Model)")
print("=" * 70)
print("\n🔧 KEY FIXES:")
print("  1. FIXED format string error (escaped curly braces)")
print("  2. REMOVED max_tokens - unlimited tokens for thinking")
print("  3. IMPROVED current/past detection:")
print("     • Counts temporal signals (current vs past terms)")
print("     • Detects date ranges (e.g., '2010-2015' = past)")
print("     • Checks if person is at another institution")
print("     • Overrides LLM when evidence is strong")
print("  4. ENHANCED prompt with clear current/past guidance")
print("  5. FIXED temperature to 0.0 - consistent output")
print("\n💡 CURRENT/PAST DETECTION:")
print("  • Past if: 3+ past terms, ended date ranges, or at other school")
print("  • Current if: 3+ current terms, recent years, more current signals")
print("  • Simple counting - no overcomplication!")
print("\n✅ This should fix classification errors!")
print("\n🎯 Next: Run Cell 9 to test improved detection!")
print("=" * 70)
# Out:
# ======================================================================
# ✓ INSTITUTION CHECKER RELOADED - ALL FIXES APPLIED
# ======================================================================
#
# 🧠 YOUR MODEL: GPT-OSS 20B (Thinking Model)
# ======================================================================
#
# 🔧 KEY FIXES:
#   1. FIXED format string error (escaped curly braces)
#   2. REMOVED max_tokens - unlimited tokens for thinking
#   3. IMPROVED current/past detection:
#      • Counts temporal signals (current vs past terms)
#      • Detects date ranges (e.g., '2010-2015' = past)
#      • Checks if person is at another institution
#      • Overrides LLM when evidence is strong
#   4. ENHANCED prompt with clear current/past guidance
#   5. FIXED temperature to 0.0 - consistent output
#
# 💡 CURRENT/PAST DETECTION:
#   • Past if: 3+ past terms, ended date ranges, or at other school
#   • Current if: 3+ current terms, recent years, more current signals
#   • Simple counting - no overcomplication!
#
# ✅ This should fix classification errors!
#
# 🎯 Next: Run Cell 9 to test improved detection!
# ======================================================================

# %% [markdown]
# ## Test Connection Fix
# Quick test to verify the connection issues are resolved.

# %%
# Quick connection and JSON parsing tests
from institution_checker.search import _get_http_client
from institution_checker.llm_processor import _parse_response, _extract_fields_with_regex
import httpx

print("🔍 RUNNING SYSTEM TESTS...")
print("=" * 70)

# Test 1: HTTP Client
print("\n1. Testing HTTP client...")
try:
    client = await _get_http_client()
    response = await client.get("https://www.bing.com", timeout=5.0)
    print(f"   ✓ HTTP client working (status {response.status_code})")
except Exception as e:
    print(f"   ✗ HTTP client failed: {e}")

# Test 2: JSON Parsing with malformed JSON
print("\n2. Testing robust JSON parsing...")
test_cases = [
    '{"connected": "Y", "confidence": "high"}',  # Valid
    '{"connected": "Y", "confidence": "high",}',  # Trailing comma
    '```json\n{"connected": "Y"}\n```',  # Code block
    '{"connected": "Y", "detail": "Professor at Purdue"}',  # Partial
]
passed = 0
for i, test in enumerate(test_cases, 1):
    try:
        result = _parse_response(test)
        if result.get("connected") in ["Y", "N"]:
            passed += 1
    except:
        pass
print(f"   ✓ Parsed {passed}/{len(test_cases)} test cases")

# Test 3: Regex fallback
print("\n3. Testing regex fallback parser...")
malformed = '"connected": "Y", "confidence": "high", "detail": "test'
try:
    result = _extract_fields_with_regex(malformed)
    if result.get("connected") == "Y":
        print(f"   ✓ Regex fallback working")
    else:
        print(f"   ⚠ Regex fallback returned: {result.get('connected')}")
except Exception as e:
    print(f"   ✗ Regex fallback failed: {e}")

print("\n" + "=" * 70)
print("✓ System tests complete. Ready to process names.")
print("=" * 70)
# Out:
# 🔍 RUNNING SYSTEM TESTS...
# ======================================================================
#
# 1. Testing HTTP client...
#    ✓ HTTP client working (status 200)
#
# 2. Testing robust JSON parsing...
#    ✓ Parsed 4/4 test cases
#
# 3. Testing regex fallback parser...
#    ✓ Regex fallback working
#
# ======================================================================
# ✓ System tests complete. Ready to process names.
# ======================================================================

# %% [markdown]
# ## 🔬 ROOT CAUSE DIAGNOSIS
# Let's see what the LLM is actually returning and why it's malformed.

# %%
# Diagnose what the LLM is actually returning
import aiohttp
import json
from institution_checker.config import LLM_API_URL, LLM_API_KEY, MODEL_NAME

print("=" * 70)
print("DIAGNOSING LLM RESPONSES")
print("=" * 70)
print(f"\nModel: {MODEL_NAME}")
print(f"API: {LLM_API_URL}")

# Simple test prompt
test_prompt = """Return ONLY this JSON with NO additional text:
{
  "connected": "Y",
  "connection_detail": "Test professor",
  "current_or_past": "current",
  "supporting_url": "https://test.edu",
  "confidence": "high",
  "temporal_evidence": "Active since 2020"
}"""

async def test_llm_response():
    async with aiohttp.ClientSession() as session:
        headers = {
            "Authorization": f"Bearer {LLM_API_KEY}",
            "Content-Type": "application/json",
        }
        payload = {
            "model": MODEL_NAME,
            "messages": [
                {"role": "system", "content": "You are a JSON generator. Return ONLY valid JSON with no text."},
                {"role": "user", "content": test_prompt},
            ],
            "temperature": 0.1,
            "max_tokens": 500,
        }
        
        print("\n📤 Sending test request...")
        async with session.post(LLM_API_URL, json=payload, headers=headers) as response:
            print(f"Status: {response.status}")
            
            text = await response.text()
            print(f"Response length: {len(text)} chars\n")
            
            # Parse the API response
            try:
                data = json.loads(text)
                print("✓ API response is valid JSON")
                
                # Get the actual content
                choices = data.get("choices", [])
                if choices:
                    content = choices[0].get("message", {}).get("content", "")
                    print(f"\n📝 LLM Content ({len(content)} chars):")
                    print("-" * 70)
                    print(content)
                    print("-" * 70)
                    
                    # Try to parse it
                    print("\n🔍 Attempting to parse as JSON...")
                    try:
                        parsed = json.loads(content)
                        print("✓ Content is VALID JSON!")
                        print(f"Keys: {list(parsed.keys())}")
                    except json.JSONDecodeError as e:
                        print(f"✗ Content is INVALID JSON!")
                        print(f"Error: {e}")
                        print(f"\nFirst 200 chars: {content[:200]}")
                        print(f"Last 200 chars: {content[-200:]}")
                        
                        # Check for common issues
                        if not content.strip().endswith("}"):
                            print("\n⚠️  ISSUE: Response doesn't end with }")
                            print("   → Likely TRUNCATED due to max_tokens limit")
                        if "```" in content:
                            print("\n⚠️  ISSUE: Response contains markdown code blocks")
                            print("   → Model not following 'no markdown' instruction")
                        if content.count('"') % 2 == 1:
                            print("\n⚠️  ISSUE: Odd number of quotes")
                            print("   → Likely truncated mid-string")
                else:
                    print("✗ No choices in API response")
                    print(f"Response data: {data}")
                    
            except json.JSONDecodeError as e:
                print(f"✗ API response is not valid JSON: {e}")
                print(f"Response text: {text[:500]}")

print("\n" + "=" * 70)
await test_llm_response()
print("=" * 70)
# Out:
# ======================================================================
# DIAGNOSING LLM RESPONSES
# ======================================================================
#
# Model: gpt-oss:latest
# API: https://genai.rcac.purdue.edu/api/chat/completions
#
# ======================================================================
#
# 📤 Sending test request...
# Status: 200
# Response length: 499 chars
#
# ✓ API response is valid JSON
#
# 📝 LLM Content (178 chars):
# ----------------------------------------------------------------------
# {"connected":"Y","connection_detail":"Test professor","current_or_past":"current","supporting_url":"https://test.edu","confidence":"high","temporal_evidence":"Active since 2020"}
# ----------------------------------------------------------------------
#
# 🔍 Attempting to parse as JSON...
# ✓ Content is VALID JSON!
# Keys: ['connected', 'connection_detail', 'current_or_past', 'supporting_url', 'confidence', 'temporal_evidence']
# ======================================================================
# Status: 200
# Response length: 499 chars
#
# ✓ API response is valid JSON
#
# 📝 LLM Content (178 chars):
# ----------------------------------------------------------------------
# {"connected":"Y","connection_detail":"Test professor","current_or_past":"current","supporting_url":"https://test.edu","confidence":"high","temporal_evidence":"Active since 2020"}
# ----------------------------------------------------------------------
#
# 🔍 Attempting to parse as JSON...
# ✓ Content is VALID JSON!
# Keys: ['connected', 'connection_detail', 'current_or_past', 'supporting_url', 'confidence', 'temporal_evidence']
# ======================================================================

# %% [markdown]
# ## Debug: Test Single Name Processing
# Test search and LLM analysis for a specific name to see what's going wrong.

# %%
# Debug a specific name to see search results and LLM response
from institution_checker.search import enhanced_search
from institution_checker.llm_processor import analyze_connection, _build_prompt
from institution_checker import INSTITUTION

# Pick a name that should have a connection but was missed
# Try: "Jozef Kokini", "Robert Duncan", "Buzz Aldrin", "Nicholas Rauh"
TEST_NAME = "Jozef Kokini"  

print("=" * 70)
print(f"DEBUGGING: {TEST_NAME}")
print("=" * 70)

# Step 1: Test search
print("\n📍 STEP 1: SEARCH")
print("-" * 70)
search_results = await enhanced_search(TEST_NAME, INSTITUTION, num_results=20, debug=False)
print(f"\n✓ Found {len(search_results)} results\n")

if search_results:
    print("Top 5 results:")
    for i, result in enumerate(search_results[:5], 1):
        print(f"\n{i}. {result.get('title', 'No title')}")
        print(f"   URL: {result.get('url', 'No URL')[:80]}...")
        snippet = result.get('snippet', 'No snippet')
        print(f"   Snippet: {snippet[:120]}...")
        signals = result.get('signals', {})
        print(f"   Score: {signals.get('relevance_score', 0)}, "
              f"Has inst: {signals.get('has_institution', False)}, "
              f"Has person: {signals.get('has_person_name', False)}")
else:
    print("⚠ WARNING: No results found!")

# Step 2: Test LLM analysis
print("\n\n📍 STEP 2: LLM ANALYSIS")
print("-" * 70)
decision = await analyze_connection(TEST_NAME, INSTITUTION, search_results, debug=True)

print("\n\n📍 FINAL DECISION:")
print("-" * 70)
for key, value in decision.items():
    print(f"  {key}: {value}")

print("\n" + "=" * 70)
# Out:
# ======================================================================
# DEBUGGING: Jozef Kokini
# ======================================================================
#
# 📍 STEP 1: SEARCH
# ----------------------------------------------------------------------
#
# ✓ Found 19 results
#
# Top 5 results:
#
# 1. EB Member Biography | Journal of Food and Nutrition | JSCHOLAR
#    URL: https://www.bing.com/ck/a?p=57e30ff914952ab5d0482692bf6fd312af9e73dc41aaf140f2ca...
#    Snippet: Dr. Jozef L. Kokini is currently the Scholle Endowed Chair in Food Processing in the Department of Food Science at Purdu...
#    Score: 18, Has inst: True, Has person: True
#
# 2. Jozef L. Kokini | Scholle Endowed Chair | Rheology 2016 ...
#    URL: https://www.bing.com/ck/a?p=0958d008dbb0f2da74ca0d4ab04c5d991d96126642fa4e9440c4...
#    Snippet: Dr. Jozef L. Kokini is currently the Scholle Endowed Chair in Food Processing in the Department of Food Science at Purdu...
#    Score: 18, Has inst: True, Has person: True
#
# 3. Speaker : The 12th International Congress on Engineering and
#    URL: https://www.bing.com/ck/a?p=9c76e9945b6a3307bf21695af1a4e0ec6d3b380d8ecbad92863a...
#    Snippet: Dr. Jozef L. Kokini he is currently in the science-winning food processor chair in the Department of food science at Pur...
#    Score: 17, Has inst: True, Has person: True
#
# 4. New Scholle chair in food science appointed at Purdue
#    URL: https://www.bing.com/ck/a?p=ca759d074241b1558ba6bb3243a7f30bda72b6898fa252100916...
#    Snippet: Dec 16, 2013 · Jozef Kokini has been chosen as the successor to World Food Prize laureate Philip E. Nelson as the Scholl...
#    Score: 16, Has inst: True, Has person: True
#
# 5. Jozef Kokini - Faculty - Purdue University (State) | OpenGovPay
#    URL: https://www.bing.com/ck/a?p=d87c9e4531d805fb020e63a49b5c4de275283c4b253538f4718e...
#    Snippet: In 2023, Jozef Kokini made $276,056 by working as a Faculty at the Purdue University (State)....
#    Score: 16, Has inst: True, Has person: True
#
#
# 📍 STEP 2: LLM ANALYSIS
# ----------------------------------------------------------------------
#
# ✓ Found 19 results
#
# Top 5 results:
#
# 1. EB Member Biography | Journal of Food and Nutrition | JSCHOLAR
#    URL: https://www.bing.com/ck/a?p=57e30ff914952ab5d0482692bf6fd312af9e73dc41aaf140f2ca...
#    Snippet: Dr. Jozef L. Kokini is currently the Scholle Endowed Chair in Food Processing in the Department of Food Science at Purdu...
#    Score: 18, Has inst: True, Has person: True
#
# 2. Jozef L. Kokini | Scholle Endowed Chair | Rheology 2016 ...
#    URL: https://www.bing.com/ck/a?p=0958d008dbb0f2da74ca0d4ab04c5d991d96126642fa4e9440c4...
#    Snippet: Dr. Jozef L. Kokini is currently the Scholle Endowed Chair in Food Processing in the Department of Food Science at Purdu...
#    Score: 18, Has inst: True, Has person: True
#
# 3. Speaker : The 12th International Congress on Engineering and
#    URL: https://www.bing.com/ck/a?p=9c76e9945b6a3307bf21695af1a4e0ec6d3b380d8ecbad92863a...
#    Snippet: Dr. Jozef L. Kokini he is currently in the science-winning food processor chair in the Department of food science at Pur...
#    Score: 17, Has inst: True, Has person: True
#
# 4. New Scholle chair in food science appointed at Purdue
#    URL: https://www.bing.com/ck/a?p=ca759d074241b1558ba6bb3243a7f30bda72b6898fa252100916...
#    Snippet: Dec 16, 2013 · Jozef Kokini has been chosen as the successor to World Food Prize laureate Philip E. Nelson as the Scholl...
#    Score: 16, Has inst: True, Has person: True
#
# 5. Jozef Kokini - Faculty - Purdue University (State) | OpenGovPay
#    URL: https://www.bing.com/ck/a?p=d87c9e4531d805fb020e63a49b5c4de275283c4b253538f4718e...
#    Snippet: In 2023, Jozef Kokini made $276,056 by working as a Faculty at the Purdue University (State)....
#    Score: 16, Has inst: True, Has person: True
#
#
# 📍 STEP 2: LLM ANALYSIS
# ----------------------------------------------------------------------
# [LLM] Response status: 200
# [LLM] Response length: 740 chars
# [LLM] Content length: 415 chars
# [LLM] Content preview: {"connected":"Y","connection_detail":"Jozef L. Kokini is a professor and holds the Scholle Endowed Chair in Food Processing in the Department of Food Science at Purdue University.","current_or_past":"...
# [LLM] Analysis complete
#
#
# 📍 FINAL DECISION:
# ----------------------------------------------------------------------
#   connected: Y
#   connection_detail: Jozef L. Kokini is a professor and holds the Scholle Endowed Chair in Food Processing in the Department of Food Science at Purdue University.
#   current_or_past: current
#   supporting_url: https://www.purdue.edu/foodscience/faculty/jozef-kokini.html
#   confidence: high
#   temporal_evidence: As of 2025, he is listed as the current Scholle Endowed Chair at Purdue University.
#
# ======================================================================
# [LLM] Response status: 200
# [LLM] Response length: 740 chars
# [LLM] Content length: 415 chars
# [LLM] Content preview: {"connected":"Y","connection_detail":"Jozef L. Kokini is a professor and holds the Scholle Endowed Chair in Food Processing in the Department of Food Science at Purdue University.","current_or_past":"...
# [LLM] Analysis complete
#
#
# 📍 FINAL DECISION:
# ----------------------------------------------------------------------
#   connected: Y
#   connection_detail: Jozef L. Kokini is a professor and holds the Scholle Endowed Chair in Food Processing in the Department of Food Science at Purdue University.
#   current_or_past: current
#   supporting_url: https://www.purdue.edu/foodscience/faculty/jozef-kokini.html
#   confidence: high
#   temporal_evidence: As of 2025, he is listed as the current Scholle Endowed Chair at Purdue University.
#
# ======================================================================

# %% [markdown]
# ## Re-run Failed Names
# Use this cell to re-process any names that had errors in the previous run.

# %%
# Find and re-run names that had errors
if pipeline_results:
    failed_names = [
        r['name'] for r in pipeline_results 
        if 'Error:' in r.get('connection_detail', '') or 'error' in r.get('temporal_evidence', '').lower()
    ]
    
    if failed_names:
        print(f"Found {len(failed_names)} failed names:")
        for name in failed_names:
            print(f"  - {name}")
        
        print("\nRe-running with improved parsing...")
        retry_results = await run_pipeline(
            failed_names,
            batch_size=max(1, int(BATCH_SIZE // 2)),  # Smaller batches for retry
            use_enhanced_search=USE_ENHANCED_SEARCH,
            inter_batch_delay=INTER_BATCH_DELAY,
            debug=True,  # Enable debug mode to see what's happening
        )
        
        # Merge results back
        result_dict = {r['name']: r for r in pipeline_results}
        for retry in retry_results:
            result_dict[retry['name']] = retry
        
        pipeline_results = list(result_dict.values())
        print(f"\n✓ Re-run complete. Updated {len(retry_results)} results.")
        
        # Show any still failing
        still_failed = [
            r['name'] for r in pipeline_results 
            if 'Error:' in r.get('connection_detail', '') or 'error' in r.get('temporal_evidence', '').lower()
        ]
        if still_failed:
            print(f"\n⚠ {len(still_failed)} names still have errors:")
            for name in still_failed:
                print(f"  - {name}")
        else:
            print("\n✓ All names processed successfully!")
    else:
        print("No failed names found. All results processed successfully!")
else:
    print("No pipeline_results found. Run the pipeline first.")
# Out:
# No failed names found. All results processed successfully!

# %% [markdown]
# ## 🔍 Results Quality Check
# Analyze results to identify any remaining issues or suspicious patterns.

# %%
# Analyze results for quality issues
if pipeline_results:
    print("=" * 70)
    print("RESULTS QUALITY ANALYSIS")
    print("=" * 70)
    
    total = len(pipeline_results)
    errors = [r for r in pipeline_results if 'Error:' in r.get('connection_detail', '') or 
              'error' in r.get('temporal_evidence', '').lower()]
    connected = [r for r in pipeline_results if r.get('connected') == 'Y']
    not_connected = [r for r in pipeline_results if r.get('connected') == 'N']
    
    print(f"\n📊 SUMMARY:")
    print(f"  Total processed: {total}")
    print(f"  Connected: {len(connected)} ({len(connected)/total*100:.1f}%)")
    print(f"  Not connected: {len(not_connected)} ({len(not_connected)/total*100:.1f}%)")
    print(f"  Errors: {len(errors)} ({len(errors)/total*100:.1f}%)")
    
    if errors:
        print(f"\n⚠️  ERRORS ({len(errors)}):")
        for r in errors:
            print(f"  - {r['name']}: {r.get('connection_detail', 'Unknown error')[:60]}...")
    
    # Check for suspiciously short details
    short_details = [r for r in connected if len(r.get('connection_detail', '')) < 30]
    if short_details:
        print(f"\n⚠️  SUSPICIOUSLY SHORT DETAILS ({len(short_details)}):")
        for r in short_details:
            print(f"  - {r['name']}: \"{r.get('connection_detail', '')}\"")
    
    # Check confidence distribution
    high_conf = len([r for r in pipeline_results if r.get('confidence') == 'high'])
    med_conf = len([r for r in pipeline_results if r.get('confidence') == 'medium'])
    low_conf = len([r for r in pipeline_results if r.get('confidence') == 'low'])
    
    print(f"\n📈 CONFIDENCE DISTRIBUTION:")
    print(f"  High: {high_conf} ({high_conf/total*100:.1f}%)")
    print(f"  Medium: {med_conf} ({med_conf/total*100:.1f}%)")
    print(f"  Low: {low_conf} ({low_conf/total*100:.1f}%)")
    
    # Show current vs past for connected
    if connected:
        current = len([r for r in connected if r.get('current_or_past') == 'current'])
        past = len([r for r in connected if r.get('current_or_past') == 'past'])
        print(f"\n🕒 TEMPORAL CLASSIFICATION (Connected only):")
        print(f"  Current: {current} ({current/len(connected)*100:.1f}%)")
        print(f"  Past: {past} ({past/len(connected)*100:.1f}%)")
    
    if errors:
        print(f"\n💡 RECOMMENDATION: Run the retry cell above to fix {len(errors)} errors")
    elif short_details:
        print(f"\n💡 RECOMMENDATION: Review {len(short_details)} results with short details")
    else:
        print(f"\n✅ ALL RESULTS LOOK GOOD!")
    
    print("=" * 70)
else:
    print("No results available. Run the pipeline first.")
# Out:
# ======================================================================
# RESULTS QUALITY ANALYSIS
# ======================================================================
#
# 📊 SUMMARY:
#   Total processed: 20
#   Connected: 14 (70.0%)
#   Not connected: 6 (30.0%)
#   Errors: 0 (0.0%)
#
# 📈 CONFIDENCE DISTRIBUTION:
#   High: 14 (70.0%)
#   Medium: 0 (0.0%)
#   Low: 6 (30.0%)
#
# 🕒 TEMPORAL CLASSIFICATION (Connected only):
#   Current: 6 (42.9%)
#   Past: 8 (57.1%)
#
# ✅ ALL RESULTS LOOK GOOD!
# ======================================================================

# %% [markdown]
# ## Review Final Results
# Display the complete DataFrame after manual retry (if performed).

# %%
if pipeline_results:
    expanded = expand_results_to_source(pipeline_results, ctx=FILE_CONTEXT)
    display(expanded if isinstance(expanded, pd.DataFrame) else pd.DataFrame(pipeline_results))
else:
    print("No results to display.")
# Out:
#                                  name        institution connected  \
# 0                       Robert Duncan  Purdue University         Y
# 1                       Mitch Daniels  Purdue University         Y
# 2                        Morgan Furze  Purdue University         Y
# 3                       Connie Weaver  Purdue University         Y
# 4                     Geoffrey Hinton  Purdue University         N
# 5            Albert Warner Overhauser  Purdue University         Y
# 6                   Isidor Isaac Rabi  Purdue University         N
# 7   Chintamani Nagesa Ramachandra Rao  Purdue University         Y
# 8                        Jane Goodall  Purdue University         N
# 9                         Marie Curie  Purdue University         N
# 10                      Nicholas Rauh  Purdue University         Y
# 11                     France Cordova  Purdue University         Y
# 12                    Steve Amireault  Purdue University         Y
# 13                         Roy Dejoie  Purdue University         Y
# 14                       Jozef Kokini  Purdue University         Y
# 15                    Paul Alivisatos  Purdue University         N
# 16                   Vernon W. Ruttan  Purdue University         Y
# 17                    William H. Gass  Purdue University         Y
# 18                      Axel Hoffmann  Purdue University         N
# 19                     Matthew Lanham  Purdue University         Y
#
#                                     connection_detail current_or_past  \
# 0   Robert Duncan is employed as an Assistant Prof...         current
# 1   Former president of Purdue University (2013-20...            past
# 2   Assistant professor in the Botany & Plant Path...         current
# 3   Former professor and head of the Department of...            past
# 4   No evidence that Geoffrey Hinton has held an e...             N/A
# 5   Professor (Stuart Distinguished Professor of P...            past
# 6   No employment, alumni, or official visiting/fe...             N/A
# 7   Alumnus (PhD graduate) from Purdue University ...            past
# 8   No evidence of employment, student, alumni, or...             N/A
# 9   Marie Curie had no employment, student, or off...             N/A
# 10  Professor Emeritus of Classics at Purdue Unive...            past
# 11              Former president of Purdue University            past
# 12  Assistant professor in the Department of Healt...         current
# 13  Clinical Associate Professor of Management and...         current
# 14  Professor and Scholle Endowed Chair in Food Pr...         current
# 15  Paul Alivisatos has only appeared as a guest s...             N/A
# 16  Vernon W. Ruttan worked as an economist at Pur...            past
# 17  He served as a professor of philosophy at Purd...            past
# 18  No evidence of employment, student status, or ...             N/A
# 19  Clinical associate professor in quantitative m...         current
#
#                                        supporting_url confidence  \
# 0    https://www.purdue.edu/academics/ogsp/ogsp/ogsp?       high
# 1   https://en.wikipedia.org/wiki/Purdue_Universit...       high
# 2       https://ag.purdue.edu/btny/Pages/default.aspx       high
# 3   https://www.bing.com/ck/a?p=5b07d17a8eed81b4cf...       high
# 4                                                            low
# 5   https://www.physics.purdue.edu/news/2012/overh...       high
# 6   https://www.nobelprize.org/prizes/physics/1944...        low
# 7        https://en-academic.com/dic.nsf/ewink/780658       high
# 8                                                            low
# 9                                                            low
# 10  https://research-news.cla.purdue.edu/2025/03/2...       high
# 11  https://www.bing.com/ck/a?p=3444497c80f88f1d3e...       high
# 12      https://www.purdue.edu/health/kinesiology/...       high
# 13  https://www.bing.com/ck/a?p=6ccf7fa07b25fb720d...       high
# 14  https://www.purdue.edu/edus/newsroom/archieve/...       high
# 15                                                           low
# 16     https://en.wikipedia.org/wiki/Vernon_W._Ruttan       high
# 17      https://en.wikipedia.org/wiki/William_H._Gass       high
# 18                                                           low
# 19  https://business.purdue.edu/journal/24/s/strat...       high
#
#                                     temporal_evidence
# 0   Employment listed for Spring 2024 and Fall 202...
# 1                                           2013-2022
# 2   Assistant professor role documented on Sep 26,...
# 3   Joined Purdue in 1978, became department head ...
# 4                                                None
# 5                                           1973-2011
# 6   Rabi's career: 1920s-1930s Columbia, 1940s Cor...
# 7                                  PhD earned in 1958
# 8   No official connection evidence found up to 2025.
# 9   Marie Curie died in 1934, and no historical re...
# 10  Taught CLCS 181 (Summer 2025) and CLCS 383 (Sp...
# 11        2007-2015 as president of Purdue University
# 12                                         2025-07-16
# 13  Teaching MGMT 382 (Fall 2025), MGMT 478 (Sprin...
# 14  2023 salary record, 2024 teaching schedule, 20...
# 15  All references are to guest lectures in 2023-2...
# 16                                          1955-1963
# 17                                          1955-1969
# 18                                               None
# 19                                               2025

# %% [markdown]
# ## Optional Export
# Write the results to a CSV file when `EXPORT_PATH` is set.

# %%
from ftfy import fix_text

if pipeline_results and EXPORT_PATH:
    export_path = Path(EXPORT_PATH).with_suffix(".xlsx")
    export_path.parent.mkdir(parents=True, exist_ok=True)
    expanded = expand_results_to_source(pipeline_results, ctx=FILE_CONTEXT)
    df_to_export = expanded if isinstance(expanded, pd.DataFrame) else pd.DataFrame(pipeline_results)
    object_columns = df_to_export.select_dtypes(include="object").columns
    if len(object_columns):
        df_to_export[object_columns] = df_to_export[object_columns].applymap(
            lambda value: fix_text(value) if isinstance(value, str) else value
        )
    df_to_export.to_excel(export_path, index=False)
    print(f"Results exported to {export_path}")
elif not pipeline_results:
    print("No results to export.")
else:
    print("EXPORT_PATH is empty; skipping export.")
# Out:
# Results exported to data\results.xlsx
# C:\Users\setiawa\AppData\Local\Temp\1\ipykernel_19540\1017273473.py:10: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_to_export[object_columns] = df_to_export[object_columns].applymap(

# %% [markdown]
# ## Cleanup
# Close shared clients so future runs start fresh.

# %%
await close_search_clients()
await close_session()
print("Cleanup complete.")
# Out:
# Cleanup complete.
